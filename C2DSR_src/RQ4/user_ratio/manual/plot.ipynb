# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# average result
df = pd.read_csv("./result/manual_drama_animation.csv",index_col=0)
df['test_Y_NDCG_10_UGF'] = df["test_Y_NDCG_10_male"]-df["test_Y_NDCG_10_female"]
df.groupby(["user_ratio","training_setting"])[['test_Y_NDCG_10',"test_Y_NDCG_10_male","test_Y_NDCG_10_female","test_Y_NDCG_10_UGF"]].mean()
# Out:
#                              test_Y_NDCG_10  test_Y_NDCG_10_male  \
# user_ratio training_setting
# 1.0        C2DSR                   0.107285             0.104862
#            our                     0.093874             0.093593
#            single                  0.112042             0.110029
# 1.5        C2DSR                   0.109020             0.112559
#            our                     0.107994             0.112173
#            single                  0.121106             0.131564
# 2.0        C2DSR                   0.125151             0.131265
#            our                     0.112572             0.113991
#            single                  0.118818             0.128171
# 2.5        C2DSR                   0.121104             0.124152
#            our                     0.106713             0.107392
#            single                  0.126578             0.133258
#
#                              test_Y_NDCG_10_female  test_Y_NDCG_10_UGF
# ...

# %%
seed = 1
df = pd.read_csv("./result/manual_drama_animation.csv",index_col=0)
df['test_Y_NDCG_10_UGF'] = df["test_Y_NDCG_10_male"]-df["test_Y_NDCG_10_female"]
df[(df['user_ratio']==2.5)&(df['seed'] == seed)][["user_ratio","training_setting",'test_Y_NDCG_10',"test_Y_NDCG_10_male","test_Y_NDCG_10_female","test_Y_NDCG_10_UGF"]]
# Out:
#    user_ratio training_setting  test_Y_NDCG_10  test_Y_NDCG_10_male  \
# 0         2.5           single        0.154560             0.163901
# 0         2.5            C2DSR        0.134904             0.131436
# 0         2.5              our        0.098335             0.092353
#
#    test_Y_NDCG_10_female  test_Y_NDCG_10_UGF
# 0               0.133004            0.030897
# 0               0.142909           -0.011473
# 0               0.112139           -0.019787

# %%
seed = 1
df = pd.read_csv("./result/manual_drama_animation.csv",index_col=0)
df['test_Y_NDCG_10_UGF'] = df["test_Y_NDCG_10_male"]-df["test_Y_NDCG_10_female"]
df[(df['seed']==seed)&(df['user_ratio']==2)][["user_ratio","training_setting",'test_Y_NDCG_10',"test_Y_NDCG_10_male","test_Y_NDCG_10_female","test_Y_NDCG_10_UGF"]]
# Out:
#    user_ratio training_setting  test_Y_NDCG_10  test_Y_NDCG_10_male  \
# 0         2.0           single        0.128062             0.137423
# 0         2.0            C2DSR        0.136833             0.149461
# 0         2.0              our        0.122001             0.121535
#
#    test_Y_NDCG_10_female  test_Y_NDCG_10_UGF
# 0               0.106461            0.030961
# 0               0.107692            0.041768
# 0               0.123077           -0.001542

# %%
seed = 1
df = pd.read_csv("./result/manual_drama_animation.csv",index_col=0)
df['test_Y_NDCG_10_UGF'] = df["test_Y_NDCG_10_male"]-df["test_Y_NDCG_10_female"]
df[(df['seed']==seed)&(df['user_ratio']==1.5)][["user_ratio","training_setting",'test_Y_NDCG_10',"test_Y_NDCG_10_male","test_Y_NDCG_10_female","test_Y_NDCG_10_UGF"]]
# Out:
#    user_ratio training_setting  test_Y_NDCG_10  test_Y_NDCG_10_male  \
# 0         1.5           single        0.117335             0.126252
# 0         1.5            C2DSR        0.116083             0.127096
# 0         1.5              our        0.095728             0.090543
#
#    test_Y_NDCG_10_female  test_Y_NDCG_10_UGF
# 0               0.096755            0.029498
# 0               0.090671            0.036425
# 0               0.107692           -0.017149
